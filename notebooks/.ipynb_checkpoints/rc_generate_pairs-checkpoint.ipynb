# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def generate_pairs(
    df,
    n_neighbors = 5,
    train = False
):
    '''
    add some documentation here
    '''
    
    orig_df = df.copy()
    
    # define and scale the location df
    location_data = df[['latitude', 'longitude']].values
    location_data = StandardScaler().fit_transform(location_data) 
    
    # define and fit the knn
    knn = NearestNeighbors(n_neighbors = min(n_neighbors + 1, len(df)), 
                           algorithm = 'kd_tree',
                           n_jobs=-1)
    knn.fit(location_data)
    
    # generate the neighbours array - index of closest n_neighbors + 1 samples to each of the samples in the location data array, including that sample istelf
    neighbors_array = knn.kneighbors(location_data,
                                     return_distance=False)

    # create column dictionaries
    cols_1 = dict(zip(orig_df.columns, [f'{col}_1' for col in orig_df.columns]))
    cols_2 = dict(zip(orig_df.columns, [f'{col}_2' for col in orig_df.columns]))

    # create dataframes needed for final join
    df_1 = orig_df
    idxs = neighbors_array.flatten()
    df_2 = df_1.iloc[idxs].reset_index().rename(columns=cols_2)

    # change df_1
    df_1['orig_index'] = df_1.index
    df_1 = pd.concat(knn.n_neighbors * [df_1],
                     ignore_index=True)
    df_1 = df_1.reset_index().rename(columns = cols_1)
    df_1 = df_1.sort_values(['orig_index', 'index'])
    df_1.drop(columns=['orig_index', 'index'],
              inplace=True)
    df_1.reset_index(drop=True, inplace=True)
    
    # create final df
    df = pd.concat([df_1, df_2],
                   axis=1)
    df = df.loc[df.id_1 != df.id_2].reset_index(drop=True)
    
    # add final match column
    if train:
        df['match'] = df['point_of_interest_1'] == df['point_of_interest_2']
        df.drop(columns=['point_of_interest_1', 'point_of_interest_2'], inplace=True)
    
    return df

# %%
train = pd.read_csv(r'C:\Users\caseyrya\Dropbox\foursquare_location_matching_data\train.csv')

# %%
train.shape
# Out:
# (1138812, 13)

# %%
test_pairs = generate_pairs(train, 5, train = True)

# %%
print(test_pairs.shape)
test_pairs.head(20)
# Out:
# (5695833, 26)
#                 id_1                name_1  latitude_1  longitude_1  \
# 0   E_000001272c6c5d  Café Stad Oudenaarde   50.859975     3.634196
# 1   E_000001272c6c5d  Café Stad Oudenaarde   50.859975     3.634196
# 2   E_000001272c6c5d  Café Stad Oudenaarde   50.859975     3.634196
# 3   E_000001272c6c5d  Café Stad Oudenaarde   50.859975     3.634196
# 4   E_000001272c6c5d  Café Stad Oudenaarde   50.859975     3.634196
# 5   E_000002eae2a589        Carioca Manero  -22.907225   -43.178244
# 6   E_000002eae2a589        Carioca Manero  -22.907225   -43.178244
# 7   E_000002eae2a589        Carioca Manero  -22.907225   -43.178244
# 8   E_000002eae2a589        Carioca Manero  -22.907225   -43.178244
# 9   E_000002eae2a589        Carioca Manero  -22.907225   -43.178244
# 10  E_000007f24ebc95      ร้านตัดผมการาเกด   13.780813   100.484900
# 11  E_000007f24ebc95      ร้านตัดผมการาเกด   13.780813   100.484900
# 12  E_000007f24ebc95      ร้านตัดผมการาเกด   13.780813   100.484900
# 13  E_000007f24ebc95      ร้านตัดผมการาเกด   13.780813   100.484900
# 14  E_000007f24ebc95      ร้านตัดผมการาเกด   13.780813   100.484900
# 15  E_000008a8ba4f48              Turkcell   37.844510    27.844202
# 16  E_000008a8ba4f48              Turkcell   37.844510    27.844202
# 17  E_000008a8ba4f48              Turkcell   37.844510    27.844202
# 18  E_000008a8ba4f48              Turkcell   37.844510    27.844202
# 19  E_000008a8ba4f48              Turkcell   37.844510    27.844202
#
#                  address_1      city_1          state_1 zip_1 country_1 url_1  \
# 0              Abdijstraat  Nederename  Oost-Vlaanderen  9700        BE   NaN
# 1              Abdijstraat  Nederename  Oost-Vlaanderen  9700        BE   NaN
# 2              Abdijstraat  Nederename  Oost-Vlaanderen  9700        BE   NaN
# 3              Abdijstraat  Nederename  Oost-Vlaanderen  9700        BE   NaN
# 4              Abdijstraat  Nederename  Oost-Vlaanderen  9700        BE   NaN
# 5                      NaN         NaN              NaN   NaN        BR   NaN
# 6                      NaN         NaN              NaN   NaN        BR   NaN
# 7                      NaN         NaN              NaN   NaN        BR   NaN
# 8                      NaN         NaN              NaN   NaN        BR   NaN
# 9                      NaN         NaN              NaN   NaN        BR   NaN
# 10                     NaN         NaN              NaN   NaN        TH   NaN
# 11                     NaN         NaN              NaN   NaN        TH   NaN
# 12                     NaN         NaN              NaN   NaN        TH   NaN
# 13                     NaN         NaN              NaN   NaN        TH   NaN
# 14                     NaN         NaN              NaN   NaN        TH   NaN
# 15  Adnan Menderes Bulvarı         NaN              NaN   NaN        TR   NaN
# 16  Adnan Menderes Bulvarı         NaN              NaN   NaN        TR   NaN
# 17  Adnan Menderes Bulvarı         NaN              NaN   NaN        TR   NaN
# 18  Adnan Menderes Bulvarı         NaN              NaN   NaN        TR   NaN
# 19  Adnan Menderes Bulvarı         NaN              NaN   NaN        TR   NaN
#
#    phone_1           categories_1    index              id_2  \
# 0      NaN                   Bars   704744  E_9e4a5adfe5b1c5
# 1      NaN                   Bars   280465  E_3ef360d8d73dcf
# 2      NaN                   Bars   366990  E_52716b9f498e53
# 3      NaN                   Bars  1090830  E_f5238107545107
# 4      NaN                   Bars     9905  E_0240ed6c6cfa9b
# 5      NaN  Brazilian Restaurants   860109  E_c12fb799a8a0e4
# 6      NaN  Brazilian Restaurants  1043520  E_ea777cbcbc9a19
# 7      NaN  Brazilian Restaurants  1012744  E_e384ed31f2c434
# 8      NaN  Brazilian Restaurants   609064  E_88ead605bf6276
# 9      NaN  Brazilian Restaurants    24873  E_0593ae90defdf8
# 10     NaN   Salons / Barbershops   812192  E_b664578fe0e8c2
# 11     NaN   Salons / Barbershops  1015921  E_e43ae70dd470cc
# 12     NaN   Salons / Barbershops   119820  E_1ade60e26a1c55
# 13     NaN   Salons / Barbershops   708655  E_9f2c5f52fc43b1
# 14     NaN   Salons / Barbershops    72040  E_101d204d3b3375
# 15     NaN     Mobile Phone Shops   288424  E_40c486192f6105
# 16     NaN     Mobile Phone Shops   718154  E_a15185a4fe376d
# 17     NaN     Mobile Phone Shops   865543  E_c26c43f23cf59e
# 18     NaN     Mobile Phone Shops   855896  E_c03acb4032c33d
# 19     NaN     Mobile Phone Shops   540584  E_797aa3edbe7f9a
#
#                       name_2  latitude_2  longitude_2  \
# 0   Frituur De Groten Honger   50.858896     3.633336
# 1   Huisarts De Lille Renaat   50.858821     3.633495
# 2            Dokter De Lille   50.858576     3.633424
# 3            Feeste t' Ename   50.855537     3.631917
# 4                   Estetika   50.855023     3.629794
# 5                      Claro  -22.907135   -43.178162
# 6                Techno Game  -22.907257   -43.177703
# 7           Largo da Carioca  -22.907069   -43.177968
# 8                  Sensorium  -22.907215   -43.177556
# 9             Dantur Turismo  -22.907112   -43.177654
# 10                 ร้านพี่นา   13.780847   100.484630
# 11  Anise Cafe' & Patisserie   13.779695   100.487102
# 12       7#11 จรัญสนิทวงศ์57   13.779517   100.486780
# 13             ร้านมังสวิรัต   13.781462   100.489335
# 14            อาหารมังสวิรัต   13.781524   100.489580
# 15              ANker travel   37.844558    27.844448
# 16                Büffe Büfe   37.844567    27.843794
# 17              Anker Travel   37.844327    27.844438
# 18             yengenin yeri   37.844314    27.844293
# 19                 Golf Cafe   37.844347    27.843695
#
#                                address_2                 city_2  \
# 0                         Abdijstraat 83             Nederename
# 1                         Abdijstraat 64             Oudenaarde
# 2                                    NaN                  Ename
# 3                      Lotharingenstraat                  Ename
# 4                                    NaN             Oudenaarde
# 5               Shopping Avenida Central         Rio De Janeiro
# 6               Shopping Avenida Central         Rio de Janeiro
# 7                        Lrg. da Carioca         Rio de Janeiro
# 8                        Ed. Av. Central         Rio de Janeiro
# 9   Av. Rio Branco, 156 Subsolo loja 134         Rio de Janeiro
# 10                                   NaN                    NaN
# 11                410 Charansnitwong rd.                    NaN
# 12                                   NaN          กรุงเทพมหานคร
# 13                 หน้าหอฉัตรนิสา จรัญ59  หน้าหอฉัตรนิสา จรัญ59
# 14                                   NaN      หอฉัตรนิสา จรัญ59
# 15          Adnan Menderes Bulvarı No 25                  Aydın
# 16                                   NaN                    NaN
# 17          Adnan Menderes Bulvarı No 25                  Aydın
# 18                   Adnan Menderes Bulv                  Aydın
# 19                         Kurtuluş Mah.                  Aydin
#
#             state_2      zip_2 country_2                        url_2  \
# 0   Oost-Vlaanderen        NaN        BE                          NaN
# 1   Oost-Vlaanderen       9700        BE                          NaN
# 2   Oost-Vlaanderen        NaN        BE                          NaN
# 3   Oost-Vlaanderen       9700        BE     http://www.enameleeft.be
# 4    Flemish Region        NaN        BE                          NaN
# 5                RJ  20040-901        BR      http://www.claro.com.br
# 6    Rio de Janeiro  20040-901        BR                          NaN
# 7                RJ  20050-020        BR                          NaN
# 8                RJ  20040-901        BR  http://www.sensorium.com.br
# 9                RJ        NaN        BR                          NaN
# 10              NaN        NaN        TH                          NaN
# 11              NaN      10700        TH                          NaN
# 12    กรุงเทพมหานคร      10700        TH                          NaN
# 13              NaN        NaN        TH                          NaN
# 14              NaN        NaN        TH                          NaN
# 15              NaN      09000        TR                          NaN
# 16              NaN        NaN        TR                          NaN
# 17           EFELER      09000        TR                          NaN
# 18              NaN        NaN        TR                          NaN
# 19            Aydın      09020        TR     http://aydingolfcafe.com
#
#                  phone_2                    categories_2  match
# 0            +3255309661                       Friteries  False
# 1            +3255304444                Doctor's Offices  False
# 2                    NaN                Doctor's Offices  False
# 3                    NaN                       Festivals  False
# 4                    NaN                 Cosmetics Shops  False
# 5                    NaN              Mobile Phone Shops  False
# 6          +552125321799               Video Game Stores  False
# 7                    NaN                          Plazas  False
# 8           552122403848                Doctor's Offices  False
# 9   21226234242122623624              Travel & Transport  False
# 10                   NaN                     Nail Salons  False
# 11             814129779                             NaN  False
# 12                   NaN              Convenience Stores  False
# 13                   NaN  Vegetarian / Vegan Restaurants  False
# 14                   NaN               Asian Restaurants  False
# 15                   NaN                 Travel Agencies  False
# 16                   NaN                     Campgrounds  False
# 17                   NaN                 Travel Agencies  False
# 18                   NaN              Recreation Centers  False
# 19            5063810560                           Cafés  False

# %%
# positive sample portion
test_pairs[test_pairs['match']==True].shape[0] / test_pairs.shape[0]
# Out:
# 0.09870847688125688
