# %%
import numpy as np
import pandas as pd
import re

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def clean_text_field(
    df,
    col
):
    '''
    add function description here
    '''
    
    df[col] = df[col].str.lower() # map all text to lower case
    df[col] = df[col].apply(lambda x: re.sub(r'[^\w\s]', '', str(x))) # remove anything that isn’t a word or a whitespace
    
    return df


def clean_data(
    df
):
    '''
    add function description here
    '''
    
    for col in df.columns:
    
        # text cleaning function
        if col in ['name','address','city','state','zip','country','url','categories']:
            df = clean_text_field(df, col)
        else:
            pass

        # removing spaces
        if col in ['zip']:
            df[col] = df[col].str.replace(' ','')
        else:
            pass

        # rounding lat / lon values
        if col in ['latitude','longitude']:
            df[col] = round(df[col], 6)
        else:
            pass
    
    return df

# %%
train = pd.read_csv(r'C:\Users\caseyrya\Dropbox\foursquare_location_matching_data\train.csv')

train.head()
# Out:
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     Café Stad Oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           Carioca Manero -22.907225  -43.178244
# 2  E_000007f24ebc95         ร้านตัดผมการาเกด  13.780813  100.484900
# 3  E_000008a8ba4f48                 Turkcell  37.844510   27.844202
# 4  E_00001d92066153  Restaurante Casa Cofiño  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# ...

# %%
df = train.copy()

# %%
df = clean_data(df)
    
print(df.dtypes)
df.head(30)
# Out:
# id                    object
# name                  object
# latitude             float64
# longitude            float64
# address               object
# city                  object
# state                 object
# zip                   object
# country               object
# url                   object
# phone                 object
# categories            object
# point_of_interest     object
# dtype: object
#                   id                                            name  \
# 0   E_000001272c6c5d                            café stad oudenaarde
# 1   E_000002eae2a589                                  carioca manero
# 2   E_000007f24ebc95                                  รานตดผมการาเกด
# 3   E_000008a8ba4f48                                        turkcell
# 4   E_00001d92066153                         restaurante casa cofiño
# 5   E_000023d8f4be44                                      island spa
# 6   E_00002a131a2bf6                               ministry of youth
# ...
