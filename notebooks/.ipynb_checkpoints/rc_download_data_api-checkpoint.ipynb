# %%
import kaggle

kaggle.api.authenticate()

kaggle.api.dataset_download_files('foursquare-location-matching',
                                  path=r'C:\Users\caseyrya\Downloads',
                                  unzip = True)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       1 import kaggle
#       3 kaggle.api.authenticate()
# ----> 5 kaggle.api.dataset_download_files('foursquare-location-matching',
#       6                                   path=r'C:\Users\caseyrya\Downloads',
#       7                                   unzip = True)
#
# File ~\Anaconda3\lib\site-packages\kaggle\api\kaggle_api_extended.py:1230, in KaggleApi.dataset_download_files(self, dataset, path, force, quiet, unzip)
#    1226 else:
#    1227     effective_path = path
#    1229 response = self.process_response(
# -> 1230     self.datasets_download_with_http_info(owner_slug=owner_slug,
#    1231                                           dataset_slug=dataset_slug,
#    1232                                           _preload_content=False))
# ...
