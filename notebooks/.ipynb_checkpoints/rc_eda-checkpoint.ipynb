# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import string
import random

# import sample submission file
train = pd.read_csv(r'C:\Users\caseyrya\Dropbox\foursquare_location_matching_data\train.csv')
pairs = pd.read_csv(r'C:\Users\caseyrya\Dropbox\foursquare_location_matching_data\pairs.csv')

# %% [markdown]
# # train

# %%
print(train.shape)
train.head()
# Out:
# (1138812, 13)
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     Café Stad Oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           Carioca Manero -22.907225  -43.178244
# 2  E_000007f24ebc95         ร้านตัดผมการาเกด  13.780813  100.484900
# 3  E_000008a8ba4f48                 Turkcell  37.844510   27.844202
# 4  E_00001d92066153  Restaurante Casa Cofiño  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# 1   NaN  Brazilian Restaurants  P_d82910d8382a83
# 2   NaN   Salons / Barbershops  P_b1066599e78477
# 3   NaN     Mobile Phone Shops  P_b2ed86905a4cd3
# 4   NaN    Spanish Restaurants  P_809a884d4407fb

# %%
print(f'duplicate rows: {len(train[train.duplicated()])}')
for col in train.columns:
    print(f'duplicate values in column "{col}": {len(train[train[col].duplicated()])}')
# Out:
# duplicate rows: 0
# duplicate values in column "id": 0
# duplicate values in column "name": 296725
# duplicate values in column "latitude": 17111
# duplicate values in column "longitude": 58539
# duplicate values in column "address": 580657
# duplicate values in column "city": 1070706
# duplicate values in column "state": 1121215
# duplicate values in column "zip": 1045482
# duplicate values in column "country": 1138590
# duplicate values in column "url": 967589
# duplicate values in column "phone": 845357
# duplicate values in column "categories": 1086233
# duplicate values in column "point_of_interest": 398840

# %%
train[train['latitude'].duplicated()].head(20)
# Out:
#                      id                                             name  \
# 535    E_0020ff8f3b06f9                             dw手表图片女士-一比一原单A货奢侈品蓬
# 1541   E_005c564d80c2d1                           高仿gucci 女士-一比一原单A货奢侈品之
# 3141   E_00bbd9375a59eb                    Home-百年灵表冠拔不出来怎么办-一比一原单A货奢侈品望
# 3167   E_00bd2a9a2d54c8                  Home-百年灵计时三眼手表怎么调时间-一比一原单A货奢侈品由
# 5595   E_0146e712d66bb8                          gucci同名男士一带-一比一原单A货奢侈品携
# 5649   E_014a49875a76e4                        高仿gucci长款钱包价格-一比一原单A货奢侈品多
# 7370   E_01ae54e7b13893                          lv包包a货一般多少钱-一比一原单A货奢侈品很
# 7406   E_01aff8ae1b6976                          gucci女士皮带宽度-一比一原单A货奢侈品山
# 9975   E_0245c89f0b1518                          gucci男士钱包推荐-一比一原单A货奢侈品儿
# 10165  E_024f81e0b8f980                     o当高仿精仿法穆兰女表多少钱一块-一比一原单A货奢侈品当
# 10957                                                NaN            NaN   NaN
# 11132  mq随高仿▊选款徾☆呺:11４３８８6８↙▊新闻频道奢侈品包包原版a货精仿法国选款徾☆呺:1...            NaN    KS
# 13049  bg就高仿▊选款薇★呺1 1 4 ３ 8 8 б ⒏▊复刻一比一原单奢侈品包包原版a货精仿法...            NaN    KS
# 13389  pd心 高 仿 包 包 拿货V信呺:l l ４ ３ ８ ８ 6 ８原版精仿男士女士鞋子衣服加...            NaN    KS
# 14072  vv父高仿▊选款徾☆呺:11４３８８6８↙▊新闻频道奢侈品包包原版a货精仿法国选款徾☆呺:1...            首页_    KS
# 14169  tn今高仿▊选款徾☆呺:11４３８８6８↙▊新闻频道奢侈品包包原版a货精仿法国选款徾☆呺:1...            NaN    KS
# 14552                                                NaN            NaN   NaN
# 14733  yt烧高仿▊选款薇★呺1143⒏⒏б⒏▊奢侈品包包原版a货精仿法国▊选款薇★呺1143⒏⒏б...            NaN    KS
#
#          zip country                           url         phone  \
# 535      NaN      US                           NaN           NaN
# 1541     NaN      US                           NaN           NaN
# 3141     NaN      US                           NaN           NaN
# 3167     NaN      US                           NaN           NaN
# 5595     NaN      US                           NaN           NaN
# 5649     NaN      US                           NaN           NaN
# 7370     NaN      US                           NaN           NaN
# 7406     NaN      US                           NaN           NaN
# 9975     NaN      US                           NaN           NaN
# 10165    NaN      US                           NaN           NaN
# 10313  94107      US  https://www.rtuckerloans.com  +15106823990
# 10655  96817      US                           NaN           NaN
# 10957    NaN      MV                           NaN           NaN
# 11132    NaN      US                           NaN           NaN
# 13049    NaN      US                           NaN           NaN
# 13389    NaN      US                           NaN           NaN
# 14072    NaN      US                           NaN           NaN
# 14169    NaN      US                           NaN           NaN
# 14552    NaN      RU                           NaN           NaN
# 14733    NaN      US                           NaN           NaN
#
#                                         categories point_of_interest
# 535                          Ethiopian Restaurants  P_1c5d451cc4c62e
# 1541                         Ethiopian Restaurants  P_dfd5bc68f2e0f5
# 3141                         Ethiopian Restaurants  P_9d7724c165205d
# 3167                         Ethiopian Restaurants  P_6b2cb5410c79b5
# 5595                         Ethiopian Restaurants  P_69622d58c8ee75
# 5649                         Ethiopian Restaurants  P_4b16e03552abc7
# 7370                         Ethiopian Restaurants  P_3b498e7f59a781
# 7406                         Ethiopian Restaurants  P_05091251ee9b32
# 9975                         Ethiopian Restaurants  P_fe37608196f8e1
# 10165                        Ethiopian Restaurants  P_4db033d9073073
# 10313                                    Buildings  P_77f3dc2fb8e868
# 10655                                 Golf Courses  P_6d461c1dbac3a3
# 10957                            Airport Terminals  P_f965fa36dc20c2
# 11132                        Ethiopian Restaurants  P_565313a9c4f69d
# 13049                        Ethiopian Restaurants  P_c095fee963eefb
# 13389                        Ethiopian Restaurants  P_4b16e03552abc7
# 14072                        Ethiopian Restaurants  P_1ee5f166aa3ebc
# 14169                        Ethiopian Restaurants  P_9e51c8b2783e4a
# 14552  Residential Buildings (Apartments / Condos)  P_f95220ae32cb18
# 14733                        Ethiopian Restaurants  P_099f5382df4085

# %% [markdown]
# # pairs
